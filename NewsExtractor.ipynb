# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import re, datetime
import pandas as pd
import numpy as np
import requests

# %%
driver = webdriver.Chrome()

# %%
driver.get("http://google.co.in")

# %%
#a=driver.page_source

# %%
textbox=driver.find_element_by_id('lst-ib')
textbox.send_keys("Iceland Food , Jobs, slowdown, profit")
driver.find_element_by_name("btnK").click()

# %%
news=driver.find_elements_by_class_name("rc")

# %%
'''for new in news:
    print(new.find_element_by_css_selector('a').get_attribute("href"))
for new in news:
    spans=new.find_elements_by_class_name("f")
    for span in spans:
        print(span.text)

for new in news:
    spans=new.find_elements_by_css_selector("span")
    for span in spans:
        print(span.text)'''

# %%
df=pd.DataFrame(columns=["Date","Link"])
links=[]
dates=[]
for new in news:
    try:
        links.append(new.find_element_by_css_selector('a').get_attribute('href'))
    except:
        links.append("no tag")
    try:
        span=new.find_element_by_css_selector('span.f')
        match = re.match('\w[A-Za-z]* \d[0-9]*, \d[0-9]*', span.text)
        dates.append(match.group())
    except:
        dates.append("no tag")

# %%
li = pd.Series(links)
dt= pd.Series(dates)
df.Date=dt.values
df.Link=li.values

# %%
df.to_csv("Iceland1.csv",sep=',',encoding='utf-8')

# %%
for row_index,row in df.iterrows():
   if row.Date
# Out:
# Jun 10, 2016
# Jun 22, 2012
# Jun 5, 2017
# Jun 10, 2011
# Jun 15, 2018
# Jun 15, 2018
# Jun 10, 2015
# no tag
# Jun 7, 2013
# Jun 12, 2009

# %%
print (datetime.date.today() - datetime.timedelta(6*365/12))
# Out:
# 2018-01-30

# %%
datetime.datetime.strptime('20-Nov-2002','%d-%b-%Y').strftime('%Y%m%d')
# Out:
# '20021120'

# %%
for row_index,row in df.iterrows():
   print(row.Link)
# Out:
# http://www.thisismoney.co.uk/money/markets/article-3635147/Iceland-posts-flat-profits-extremely-challenging-UK-grocery-market-takes-toll-frozen-food-chain.html
# http://www.thisismoney.co.uk/money/markets/article-2163174/Record-results-frozen-food-chain-Iceland-profits-rise-18-5.html
# https://www.retailgazette.co.uk/blog/2017/06/iceland-revamp-pays-off-profits-soar/
# https://www.theguardian.com/business/2011/jun/10/iceland-supermarket-record-profits-drive-up-bid-price
# http://btvi.in/article/read/industry/79660/iceland-sees-first-half-earnings-slowdown-this-year?mm-options=value-toppers
# https://www.insider.co.uk/company-results-forecasts/iceland-profits-dip-supply-investment-12712009
# https://www.telegraph.co.uk/finance/newsbysector/retailandconsumer/11665416/Iceland-suffers-sharp-fall-in-sales-and-profits.html
# https://www.indeed.co.uk/cmp/Iceland-Foods-Ltd/reviews
# https://www.walesonline.co.uk/business/business-news/frozen-food-retailer-iceland-reveals-4208203
# ...

# %%
pages=[]
for row_index,row in df.iterrows():
   pages.append(requests.get(row.Link))

# %%
a=requests.get("http://www.thisismoney.co.uk/money/markets/article-3635147/Iceland-posts-flat-profits-extremely-challenging-UK-grocery-market-takes-toll-frozen-food-chain.html")

# %%
soup=[]
for page in pages:
    soup.append(BeautifulSoup(page.content, 'html.parser'))

# %%
a=soup[1].prettify()

# %%
list(soup[1].children)
# Out:
# ['html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "//www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd"',
#  <html><head><!--class fe.views.page_modules.Head-->
#  <!--class fe.views.head_modules.Favicon-->
#  <link href="/favicon.ico?v=2" rel="icon"/>
#  <!--class fe.views.head_modules.Title-->
#  <title>Record results at frozen food chain Iceland as profits rise by 18.5% | This is Money</title>
#  <!--class fe.views.preload.Preload-->
#  <link href="//i.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//video.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//scripts.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//rta.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//ted.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//t.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//i.dailymail.co.uk/" rel="dns-prefetch"/>
#  <link href="//i.dailymail.co.uk" rel="preconnect"/>
#  <link href="//video.dailymail.co.uk" rel="preconnect"/>
# ...

# %%
[type(item) for item in list(soup[1].children)]
# Out:
# [bs4.element.Doctype,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.NavigableString,
#  bs4.element.Comment,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString,
# ...

# %%
html = list(soup[1].children)[1]

# %%
list(html.children)
# Out:
# [<head><!--class fe.views.page_modules.Head-->
#  <!--class fe.views.head_modules.Favicon-->
#  <link href="/favicon.ico?v=2" rel="icon"/>
#  <!--class fe.views.head_modules.Title-->
#  <title>Record results at frozen food chain Iceland as profits rise by 18.5% | This is Money</title>
#  <!--class fe.views.preload.Preload-->
#  <link href="//i.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//video.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//scripts.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//rta.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//ted.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//t.dailymail.co.uk" rel="dns-prefetch"/>
#  <link href="//i.dailymail.co.uk/" rel="dns-prefetch"/>
#  <link href="//i.dailymail.co.uk" rel="preconnect"/>
#  <link href="//video.dailymail.co.uk" rel="preconnect"/>
#  <link href="//scripts.dailymail.co.uk" rel="preconnect"/>
#  <link href="//rta.dailymail.co.uk" rel="preconnect"/>
# ...

# %%
body = list(html.children)[1]

# %%
allTags=list(body.children)

# %%
a=allTags[46]

# %%
print(a.get_text())
# Out:
#
#
#
#
#
# Money Home
#
#
# Markets
#
#
# Saving & banking
#
#
# Investing
#
#
# Bills
#
#
# Cars
#
#
# Holidays
#
#
# Cards & loans
#
#
# Pensions
#
#
# Mortgages & home
#
#
# Experts
#
#
# Buy-to-let
#
#
#
# My Profile
# Logout
#
#
#
#
#
#               Login
#
#
#
#
#                 var logout_comp = document.getElementById('logout_comp'),
#                     login_comp = document.getElementById('login_comp');
#                 if(DM.isLoggedIn){
#                     login_comp.style.display = 'none';
#                     logout_comp.style.display = 'block';
#                 }
#
#
#
#
# Wednesday, Aug 1st 2018
# 6AM
# 28°C
# 9AM
# 28°C
#
# 5-Day Forecast
#
#
#
#
#
# adverts.addToArray({"pos":"billboard","dcopt":true})Advertisement
#  show ad
#
#
#
#
#
#
#
#
#
#
# The very modern family businesses... run by children: The bright young things who have recruited mum, grandad and even a little sister to sell fashion online
#
#
#
#
#
# ...

# %%
a=soup[1].find_all('p')

# %%
for b in a:
    print(str(len(b.get_text()))+" ************ "+b.get_text())
# Out:
# 27 ************ By
#
# This Is Money Reporter
#
# 79 ************
# Published:
#   14:34 BST, 22 June 2012
#
#  |
# Updated:
#   14:34 BST, 22 June 2012
#
#
# 0 ************
# 14 ************ View  comments
# 168 ************
# Frozen food chain Iceland unveiled record profits today but warned that vouchers from supermarket rivals used to attract cash-strapped customers were impacting trade.
# 194 ************
# The group, which has 814 stores across the UK and employs 24,000 staff, said like-for-like sales rose by 6 per cent, pushing profits up 18.5 per cent to £184.3million for the year to March 30.
# 290 ************
# Iceland's profits rise represents its seventh set of record results in a
#  row since Malcom Walker, who founded the firm in 1970, returned to the business in 2005 after losing his job in 2001 following a controversial shares sale.
#
# Sales have also grown every year since Mr Walker's return.
# ...

# %%
for b in a:
    print((b))
# Out:
# <p class="author-section byline-plain">By
#
# <a class="author" href="/home/search.html?s=&amp;authornamef=This+Is+Money+Reporter" rel="nofollow">This Is Money Reporter</a>
# </p>
# <p class="byline-section"><span class="article-timestamp article-timestamp-published">
# <span class="article-timestamp-label">Published:</span>
#   14:34 BST, 22 June 2012
# </span>
#  | <span class="article-timestamp article-timestamp-updated">
# <span class="article-timestamp-label">Updated:</span>
#   14:34 BST, 22 June 2012
# </span>
# </p>
# <p class="count-number"></p>
# <p class="count-text">View <br/> comments</p>
# <p>
# <font style="font-size: 1.2em;">Frozen food chain Iceland unveiled record profits today but warned that vouchers from supermarket rivals used to attract cash-strapped customers were impacting trade. <br/></font></p>
# <p><font style="font-size: 1.2em;">
# ...
